# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset:
#
# Import the necessary libraries and create your dataframe(s).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

weather_df = pd.read_csv("GlobalWeatherRepository.csv")

weather_df.info()
weather_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       1949 non-null   object
#  1   location_name                 1949 non-null   object
#  2   latitude                      1949 non-null   float64
#  3   longitude                     1949 non-null   float64
#  4   timezone                      1949 non-null   object
#  5   last_updated_epoch            1949 non-null   int64
#  6   last_updated                  1949 non-null   object
#  7   temperature_celsius           1949 non-null   float64
#  8   temperature_fahrenheit        1949 non-null   float64
#  9   condition_text                1949 non-null   object
#  10  wind_mph                      1949 non-null   float64
#  11  wind_kph                      1949 non-null   float64
# ...

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
# To check if there is any missing data used the following
weather_df.isna().sum()

# There is no any missing data I can found
# Out:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# ...

# %%
weather_df.nunique()
# Out:
# country                         184
# location_name                   195
# latitude                        191
# longitude                       192
# timezone                        182
# last_updated_epoch               17
# last_updated                    315
# temperature_celsius             232
# temperature_fahrenheit          232
# condition_text                   21
# wind_mph                         86
# wind_kph                         86
# wind_degree                     293
# wind_direction                   16
# pressure_mb                      40
# pressure_in                      93
# precip_mm                        61
# precip_in                        37
# humidity                         90
# cloud                            93
# feels_like_celsius              368
# feels_like_fahrenheit           517
# visibility_km                    28
# visibility_miles                 12
# uv_index                         10
# gust_mph                        151
# ...

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
# I have not seen the Irregular data or outliers in this data set.
weather_df.describe()

#weather_df.dtypes
# Out:
#           latitude    longitude  last_updated_epoch  temperature_celsius  \
# count  1949.000000  1949.000000        1.949000e+03          1949.000000
# mean     19.311555    21.745346        1.693659e+09            22.438379
# std      24.578988    65.606917        2.407481e+05             6.544515
# min     -41.300000  -175.200000        1.693301e+09             2.900000
# 25%       3.750000    -6.840000        1.693439e+09            17.200000
# 50%      17.250000    23.240000        1.693697e+09            23.300000
# 75%      41.330000    50.580000        1.693870e+09            27.700000
# max      63.830000   179.220000        1.694042e+09            45.000000
#
#        temperature_fahrenheit     wind_mph     wind_kph  wind_degree  \
# count             1949.000000  1949.000000  1949.000000  1949.000000
# mean                72.389123     6.617701    10.647922   166.163161
# std                 11.780242     4.554719     7.334053   102.186723
# ...

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
# For my analysis for this dataset, I feel following are redandant so removing them
# last_updated_epoch             
# last_updated                    
# condition_text                 
# wind_mph                       
# wind_kph                       
# uv_index                        
# gust_mph                        
# gust_kph               
# air_quality_Carbon_Monoxide     
# air_quality_Ozone               
# air_quality_Nitrogen_dioxide    
# air_quality_Sulphur_dioxide     
# air_quality_PM2.5               
# air_quality_PM10                
# air_quality_us-epa-index        
# air_quality_gb-defra-index      

#weather_df.boxplot(column=['temperature_fahrenheit'])
weather_cleaned_df = weather_df.drop(columns=['last_updated_epoch','last_updated','condition_text','wind_mph','wind_kph',
                                              'uv_index','gust_mph','gust_kph','air_quality_Carbon_Monoxide',
                                              'air_quality_Ozone','air_quality_Ozone','air_quality_Nitrogen_dioxide',
                                               'air_quality_Sulphur_dioxide','air_quality_PM2.5','air_quality_PM10',
                                                'air_quality_us-epa-index','air_quality_gb-defra-index'])

# %%
weather_cleaned_df.info()
weather_cleaned_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 1949 non-null   object
#  1   location_name           1949 non-null   object
#  2   latitude                1949 non-null   float64
#  3   longitude               1949 non-null   float64
#  4   timezone                1949 non-null   object
#  5   temperature_celsius     1949 non-null   float64
#  6   temperature_fahrenheit  1949 non-null   float64
#  7   wind_degree             1949 non-null   int64
#  8   wind_direction          1949 non-null   object
#  9   pressure_mb             1949 non-null   float64
#  10  pressure_in             1949 non-null   float64
#  11  precip_mm               1949 non-null   float64
#  12  precip_in               1949 non-null   float64
#  13  humidity                1949 non-null   int64
# ...

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
#Exporting the DataFrame as a CSV file
#weather_cleaner_df.to_csv(“cleaned_weather_repository.csv”)

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset?
#    There is no dirty data in my dataset.
# 2. Did the process of cleaning your data give you new insights into your dataset?
#    For my analysis I feel few columns were unnecessary so drop them for analysis purpose.
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations?
#    I will like to do vizualization for temperature, humidity variations, and the location depends on longitute and latitude.  That may help me to do analysis of climate change and also if someone wants to travel at particular location will help to analyze the weatehr patterns. I will use the columns as if necessary for visualization.
